# %%
# %matplotlib inline
import openpyx
import pandas as pd
import numpy as np
import scipy.stats 
import scipy
import seaborn as sns
import matplotlib.pylab as plt
import networkx as nx


data = pd.read_csv("https://labonline.ctu.unimi.it/pluginfile.php/208010/mod_resource/content/1/AB_NYC_2019.csv", 
                        on_bad_lines='skip')

data
# Out:
#                                        <!DOCTYPE html>
# 0          <html xmlns="http://www.w3.org/1999/xhtml">
# 1                                        <head><title>
# 2                \tLaboratori on line - Autenticazione
# 3                                             </title>
# 4    \t<script src="https://ajax.googleapis.com/aja...
# ..                                                 ...
# 385                                           \t</div>
# 386                                         \t<script>
# 387                                        \t</script>
# 388                                            </body>
# 389                                            </html>
#
# [390 rows x 1 columns]
